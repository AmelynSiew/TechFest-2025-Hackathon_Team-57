# %% [markdown]
# <a href="https://colab.research.google.com/github/AmelynSiew/TechFest-2025-Hackathon_Team-57/blob/main/api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: pip install google-generativeai google-search-results

# !pip install google-generativeai google-search-results

# %%
import google.generativeai as genai
from serpapi import GoogleSearch

# %%
# Configure Gemini API
genai.configure(api_key="AIzaSyCwKTkFYK7hM2NZlUW0LI6i0pVXZl6zJn4")

# %%
# Function to extract key factual statements from text
def extract_facts(text):
    model = genai.GenerativeModel("gemini-pro")
    prompt = f"Extract key factual statements from the following text:\n\n{text}\n\nReturn them as a numbered list."
    response = model.generate_content(prompt)
    return response.text  # Returns extracted facts

# %%
# Function to search the web for fact-checking
def search_web(query):
    params = {
        "q": query,
        "hl": "en",
        "gl": "us",
        "api_key": "YOUR_SERPAPI_KEY"  # Replace with your SerpAPI key
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    return results.get("organic_results", [])[:3]  # Get top 3 search results

# %%
# Function to verify facts using Gemini + web search
def verify_fact(fact):
    sources = search_web(fact)  # Get web results
    source_texts = "\n\n".join([s["snippet"] for s in sources])  # Extract summaries

    model = genai.GenerativeModel("gemini-pro")
    prompt = f"""
    Compare the following fact with the provided sources and determine if it is true, misleading, or false.

    Fact: "{fact}"

    Sources:
    {source_texts}

    Provide a fact-checking report with a True/False/Misleading label and a short explanation.
    """
    response = model.generate_content(prompt)
    return response.text

# %%
# Main function to extract and fact-check statements
def fact_check_text(text):
    print("\nExtracting facts...")
    extracted_facts = extract_facts(text).split("\n")

    results = {}
    for fact in extracted_facts:
        fact = fact.strip()
        if fact:
            print(f"\nFact-checking: {fact}")
            check_result = verify_fact(fact)
            results[fact] = check_result
            print(check_result)

    return results

# %%
# Example Input Text
input_text = """
The Great Wall of China is visible from space.
Water boils at 100 degrees Celsius at sea level.
The Eiffel Tower was completed in 1889.
"""

# %%
# Run the fact-checking system
fact_check_results = fact_check_text(input_text)
# Out:
# Extracting facts...
# WARNING:tornado.access:404 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 734.41ms
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-76-5aed8b0f4ff3> in <cell line: 0>()
#       1 # Run the fact-checking system
# ----> 2 fact_check_results = fact_check_text(input_text)
#
# <ipython-input-74-57acefc47a31> in fact_check_text(text)
#       2 def fact_check_text(text):
#       3     print("\nExtracting facts...")
# ----> 4     extracted_facts = extract_facts(text).split("\n")
#       5
#       6     results = {}
#
# <ipython-input-71-f42f667d77fc> in extract_facts(text)
#       3     model = genai.GenerativeModel("gemini-pro")
#       4     prompt = f"Extract key factual statements from the following text:\n\n{text}\n\nReturn them as a numbered list."
# ...
